# %%
import pandas as pd

# %% [markdown]
# ## dataset link - https://archive.ics.uci.edu/ml/datasets/Bank+Marketing

# %%
df_bnk = pd.read_csv('C:\\Users\\RAJNEESH BHARTI\\Desktop\\ineouron\\live class\\pandas\\bank\\bank.csv', sep =';')

# %%
df_bnk
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 0     cellular   19   oct        79         1     -1         0  unknown  no
# 1     cellular   11   may       220         1    339         4  failure  no
# 2     cellular   16   apr       185         1    330         1  failure  no
# 3      unknown    3   jun       199         4     -1         0  unknown  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no
#
# [4521 rows x 17 columns]

# %% [markdown]
# ## 1 . how many campaign available in this dataset .

# %% [markdown]
# ## 2 . how many users do we have with housing and personal loan .

# %%
df_bnk[(df_bnk["housing"] == 'yes') & (df_bnk["loan"] == 'yes' )]
# Out:
#       age            job  marital  education default  balance housing loan  \
# 1      33       services  married  secondary      no     4789     yes  yes
# 3      30     management  married   tertiary      no     1476     yes  yes
# 9      43       services  married    primary      no      -88     yes  yes
# 14     31    blue-collar  married  secondary      no      360     yes  yes
# 48     32   entrepreneur   single    primary     yes     -849     yes  yes
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4502   42       services  married  secondary      no      -91     yes  yes
# 4504   42    blue-collar   single  secondary      no     1080     yes  yes
# 4508   42         admin.  married    unknown      no      642     yes  yes
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# 1     cellular   11   may       220         1    339         4  failure   no
# 3      unknown    3   jun       199         4     -1         0  unknown   no
# 9     cellular   17   apr       313         1    147         2  failure   no
# 14    cellular   29   jan        89         1    241         1  failure   no
# 48    cellular    4   feb       204         1     -1         0  unknown   no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ...
# 4502  cellular    5   feb        43         1     -1         0  unknown   no
# 4504  cellular   13   may       951         3    370         4  failure  yes
# 4508   unknown   16   may       509         2     -1         0  unknown   no
# 4517   unknown    9   may       153         1     -1         0  unknown   no
# 4520  cellular    3   apr       345         2    249         7    other   no
#
# [406 rows x 17 columns]

# %% [markdown]
# ## 3 . how many person do we have whose age is 60+ .

# %%
len(df_bnk[df_bnk["age"] >60])
# Out:
# 127

# %% [markdown]
# ## 4 . in which month we have trageted most of the customer .

# %% [markdown]
# ## 5 . which mode of call is giving you more result

# %% [markdown]
# ## 6 . how many enterpeures do we have in this list .

# %%
len(df_bnk[df_bnk['job'] == 'entrepreneur'])
# Out:
# 168

# %% [markdown]
# ### 7 . how many customers do we have with negative balance .

# %%
len(df_bnk[df_bnk['balance'] < 0])
# Out:
# 366

# %% [markdown]
# ## 8 . prepare a group of data based on education level .

# %% [markdown]
# ## For titanic datset :

# %%
df =pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ## 1 . Find out how many male and female passenger was onboarded .

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
type(df["Sex"])  ##-- single colmn and row is series datatype it is equal to list
# Out:
# pandas.core.series.Series

# %%
df["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# ## 2 . how many survived we have .

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# ## 3 . how many casuality we have

# %% [markdown]
# ## 4 . what is name of a person who is the eldest one .

# %%
df[["Name","Age"]].max()
# Out:
# Name    van Melkebeke, Mr. Philemon
# Age                            80.0
# dtype: object

# %% [markdown]
# ## 5 . how many passenger do we have in first , second and third class .

# %%
#len(df[df['Pclass'] == 1  and df['Pclass'] == 2 and  df['Pclass'] == 3])
len(df[df['Pclass'] == 1])
# Out:
# 216

# %%
len(df[df['Pclass'] == 3])
# Out:
# 491

# %%
len(df[df['Pclass'] == 2])
# Out:
# 184

# %% [markdown]
# ## 6 . how many person we have whose name starts with "s".

# %%
df[df['Name'].str.startswith('S')]
# Out:
#      PassengerId  Survived  Pclass  \
# 10            11         1       3
# 12            13         0       3
# 23            24         1       1
# 31            32         1       1
# 48            49         0       3
# ..           ...       ...     ...
# 851          852         0       3
# 862          863         1       1
# 863          864         0       3
# 880          881         1       2
# 884          885         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 48                                 Samaan, Mr. Youssef    male   NaN      2
# ..                                                 ...     ...   ...    ...
# 851                                Svensson, Mr. Johan    male  74.0      0
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   NaN      8
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 884                             Sutehall, Mr. Henry Jr    male  25.0      0
#
#      Parch           Ticket      Fare Cabin Embarked  sub
# 10       1          PP 9549   16.7000    G6        S    2
# 12       0        A/5. 2151    8.0500   NaN        S    0
# 23       0           113788   35.5000    A6        S    0
# 31       0         PC 17569  146.5208   B78        C    1
# 48       0             2662   21.6792   NaN        C    2
# ..     ...              ...       ...   ...      ...  ...
# 851      0           347060    7.7750   NaN        S    0
# 862      0            17466   25.9292   D17        S    0
# 863      2         CA. 2343   69.5500   NaN        S   10
# 880      1           230433   26.0000   NaN        S    1
# 884      0  SOTON/OQ 392076    7.0500   NaN        S    0
#
# [86 rows x 13 columns]

# %% [markdown]
# ## 7 . try to create a new column which is a summation  of "SibSp" and "parch".

# %%
df["sub"] =df['SibSp']+df['Parch']

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked  sub
# 0      0  A/5 21171  7.25   NaN        S    1

# %% [markdown]
# ## 8 . how many person do we have below age of 25 .

# %%
df_age = df[df["Age"] < 25]

# %%
df_age
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 0              1         0       3              Braund, Mr. Owen Harris
# 7              8         0       3       Palsson, Master. Gosta Leonard
# 9             10         1       2  Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3      Sandstrom, Miss. Marguerite Rut
# 12            13         0       3       Saundercock, Mr. William Henry
# ..           ...       ...     ...                                  ...
# 875          876         1       3     Najib, Miss. Adele Kiamie "Jane"
# 876          877         0       3        Gustafsson, Mr. Alfred Ossian
# 877          878         0       3                 Petroff, Mr. Nedelio
# 882          883         0       3         Dahlberg, Miss. Gerda Ulrika
# 887          888         1       1         Graham, Miss. Margaret Edith
#
#         Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked  sub
# 0      male  22.0      1      0  A/5 21171   7.2500   NaN        S    1
# 7      male   2.0      3      1     349909  21.0750   NaN        S    4
# 9    female  14.0      1      0     237736  30.0708   NaN        C    1
# 10   female   4.0      1      1    PP 9549  16.7000    G6        S    2
# 12     male  20.0      0      0  A/5. 2151   8.0500   NaN        S    0
# ..      ...   ...    ...    ...        ...      ...   ...      ...  ...
# 875  female  15.0      0      0       2667   7.2250   NaN        C    0
# 876    male  20.0      0      0       7534   9.8458   NaN        S    0
# 877    male  19.0      0      0     349212   7.8958   NaN        S    0
# 882  female  22.0      0      0       7552  10.5167   NaN        S    0
# 887  female  19.0      0      0     112053  30.0000   B42        S    0
#
# [278 rows x 13 columns]

# %% [markdown]
# ## 9 . how many person died whose age was less then 40 .

# %%
df_died = df[df['Survived'] == 0]

# %%
df_died[df_died["Age"] <40]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 0              1         0       3               Braund, Mr. Owen Harris
# 4              5         0       3              Allen, Mr. William Henry
# 7              8         0       3        Palsson, Master. Gosta Leonard
# 12            13         0       3        Saundercock, Mr. William Henry
# 13            14         0       3           Andersson, Mr. Anders Johan
# ..           ...       ...     ...                                   ...
# 883          884         0       2         Banfield, Mr. Frederick James
# 884          885         0       3                Sutehall, Mr. Henry Jr
# 885          886         0       3  Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                 Montvila, Rev. Juozas
# 890          891         0       3                   Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket    Fare Cabin Embarked  sub
# 0      male  22.0      1      0         A/5 21171   7.250   NaN        S    1
# 4      male  35.0      0      0            373450   8.050   NaN        S    0
# 7      male   2.0      3      1            349909  21.075   NaN        S    4
# 12     male  20.0      0      0         A/5. 2151   8.050   NaN        S    0
# 13     male  39.0      1      5            347082  31.275   NaN        S    6
# ..      ...   ...    ...    ...               ...     ...   ...      ...  ...
# 883    male  28.0      0      0  C.A./SOTON 34068  10.500   NaN        S    0
# 884    male  25.0      0      0   SOTON/OQ 392076   7.050   NaN        S    0
# 885  female  39.0      0      5            382652  29.125   NaN        Q    5
# 886    male  27.0      0      0            211536  13.000   NaN        S    0
# 890    male  32.0      0      0            370376   7.750   NaN        Q    0
#
# [322 rows x 13 columns]

# %% [markdown]
# ## 10. from a  cabin column seperate text and numeric value .

# %%
df_removena=df['Cabin'].dropna().head(2)

# %%
df_removena
# Out:
# 1     C85
# 3    C123
# Name: Cabin, dtype: object

# %%
df["text"]= df['Cabin'].str.extract(r'([A-Z]+)', expand=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  sub text
# 0        0         A/5 21171   7.2500   NaN        S    1  NaN
# 1        0          PC 17599  71.2833   C85        C    1    C
# 2        0  STON/O2. 3101282   7.9250   NaN        S    0  NaN
# 3        0            113803  53.1000  C123        S    1    C
# 4        0            373450   8.0500   NaN        S    0  NaN
# ..     ...               ...      ...   ...      ...  ...  ...
# 886      0            211536  13.0000   NaN        S    0  NaN
# 887      0            112053  30.0000   B42        S    0    B
# 888      2        W./C. 6607  23.4500   NaN        S    3  NaN
# 889      0            111369  30.0000  C148        C    0    C
# 890      0            370376   7.7500   NaN        Q    0  NaN
#
# [891 rows x 14 columns]

# %%
df['Num']= df['Cabin'].str.extract(r'([0-9]+)', expand=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  sub text  Num
# 0        0         A/5 21171   7.2500   NaN        S    1  NaN  NaN
# 1        0          PC 17599  71.2833   C85        C    1    C   85
# 2        0  STON/O2. 3101282   7.9250   NaN        S    0  NaN  NaN
# 3        0            113803  53.1000  C123        S    1    C  123
# 4        0            373450   8.0500   NaN        S    0  NaN  NaN
# ..     ...               ...      ...   ...      ...  ...  ...  ...
# 886      0            211536  13.0000   NaN        S    0  NaN  NaN
# 887      0            112053  30.0000   B42        S    0    B   42
# 888      2        W./C. 6607  23.4500   NaN        S    3  NaN  NaN
# 889      0            111369  30.0000  C148        C    0    C  148
# 890      0            370376   7.7500   NaN        Q    0  NaN  NaN
#
# [891 rows x 15 columns]
